# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
# Add helper functions to append conversation
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)

    return message.content[0].text

# %%
messages = []

system_prompt = """
You are an expert Python engineer that writes concise code.
"""
add_user_message(messages, "Write a Python function that checks a string for duplicate characters")
chat(messages, system=system_prompt)
# Out:
# '## Duplicate Character Checker\n\nHere\'s a Python function that checks a string for duplicate characters, along with several variations:\n\n```python\ndef has_duplicates(string: str) -> bool:\n    """Check if a string contains any duplicate characters."""\n    return len(string) != len(set(string))\n\n\ndef find_duplicates(string: str) -> set:\n    """Return a set of all duplicate characters in a string."""\n    seen = set()\n    duplicates = set()\n\n    for char in string:\n        if char in seen:\n            duplicates.add(char)\n        else:\n            seen.add(char)\n\n    return duplicates\n\n\ndef count_duplicates(string: str) -> dict:\n    """Return a dictionary with duplicate characters and their counts."""\n    char_count = {}\n\n    for char in string:\n        char_count[char] = char_count.get(char, 0) + 1\n\n    return {char: count for char, count in char_count.items() if count > 1}\n\n\ndef duplicate_report(string: str) -> None:\n    """Print a detailed report of duplicate characters in a string."""\n    duplicates = count_duplicates(string)\n\n    if not duplicates:\n        print(f"✅ No duplicate characters found in \'{string}\'")\n        return\n\n    print(f"❌ Duplicate characters found in \'{string}\':")\n    for char, count in sorted(duplicates.items()):\n        display_char = repr(char) if char == " " else char\n        print(f"   \'{display_char}\' appears {count} times")\n\n\n# ── Example Usage ────────────────────────────────────────────────────────────\n\nif __name__ == "__main__":\n    test_strings = ["hello", "world", "python", "abcdef", "mississippi"]\n\n    print("=== has_duplicates() ===")\n    for s in test_strings:\n        print(f"  \'{s}\': {has_duplicates(s)}")\n\n    print("\\n=== find_duplicates() ===")\n    for s in test_strings:\n        print(f"  \'{s}\': {find_duplicates(s)}")\n\n    print("\\n=== count_duplicates() ===")\n    for s in test_strings:\n        print(f"  \'{s}\': {count_duplicates(s)}")\n\n    print("\\n=== duplicate_report() ===")\n    for s in test_strings:\n        duplicate_report(s)\n```\n\n### Sample Output\n\n```\n=== has_duplicates() ===\n  \'hello\': True\n  \'world\': False\n  \'python\': False\n  \'abcdef\': False\n  \'mississippi\': True\n\n=== find_duplicates() ===\n  \'hello\': {\'l\'}\n  \'world\': set()\n  \'python\': set()\n  \'abcdef\': set()\n  \'mississippi\': {\'s\', \'i\', \'p\'}\n\n=== count_duplicates() ===\n  \'hello\': {\'l\': 2}\n  \'world\': {}\n  \'python\': {}\n  \'abcdef\': {}\n  \'mississippi\': {\'s\': 4, \'i\': 4, \'p\': 2}\n\n=== duplicate_report() ===\n✅ No duplicate characters found in \'world\'\n❌ Duplicate characters found in \'mississippi\':\n   \'i\' appears 4 times\n   \'p\' appears 2 times\n   \'s\' appears 4 times\n```\n\n### Key Concepts Used\n\n| Function | Approach | Best For |\n|---|---|---|\n| `has_duplicates` | `set` comparison | Quick yes/no check |\n| `find_duplicates` | Manual iteration | Getting unique duplicates |\n| `count_duplicates` | Dictionary counting | Frequency analysis |\n| `duplicate_report` | Formatted output | Human-readable results |\n\n> **Tip:** If you need **case-insensitive** checking, convert the string first:\n> ```python\n> has_duplicates(string.lower())\n> ```'
