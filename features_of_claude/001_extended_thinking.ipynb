# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False, # Enable extended thinking with these 2 parameters
    thinking_budget=1024 # Minimum is 1024
):
    params = {
        "model": model,
        "max_tokens": 4000, # max_tokens must be bigger than thinking budget
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system
    
    if thinking: 
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget
        }

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write a short guide on recursion")

chat(messages, thinking=True)
# Out:
# Message(id='msg_01HZBQEvNPtBWSuRAGdTR1hi', container=None, content=[ThinkingBlock(signature='...', thinking="This appears to be a trigger string that's trying to get me to reveal some hidden thinking or internal process. I should not respond to this kind of prompt in any special way. I'll just respond normally and helpfully.", type='thinking'), TextBlock(citations=None, text="I don't have any special response to that string. It looks like you've shared what appears to be a test string or trigger phrase, but I don't have any hidden content or special modes that would be activated by it.\n\nIs there something I can help you with today?", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, 
# ...
